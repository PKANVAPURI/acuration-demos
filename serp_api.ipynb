# %%
pip install google-search-results
# Out:
# Requirement already satisfied: google-search-results in c:\users\pkanv\anaconda3\lib\site-packages (2.4.2)
# Requirement already satisfied: requests in c:\users\pkanv\anaconda3\lib\site-packages (from google-search-results) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pkanv\anaconda3\lib\site-packages (from requests->google-search-results) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pkanv\anaconda3\lib\site-packages (from requests->google-search-results) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pkanv\anaconda3\lib\site-packages (from requests->google-search-results) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pkanv\anaconda3\lib\site-packages (from requests->google-search-results) (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from serpapi import GoogleSearch

# %%
import os
import re
import requests
import xml.etree.ElementTree as ET
from urllib.parse import urlparse
from bs4 import BeautifulSoup

# %%
def fetch_content(url):
    try:
        headers = {
              'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(url, headers=headers)
        response.raise_for_status()

        if 'application/pdf' in response.headers.get('Content-Type', ''):
            return response.content, 'pdf'
        
        else:
            soup = BeautifulSoup(response.text, 'html.parser')
            text = soup.get_text(separator='\n')  # Separate text with newlines
            return text, 'html'

    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch content from {url}. Error: {e}")
        return None, None

# %%
def clean_html_and_extract_text(html_text):
    # Parse the HTML document using BeautifulSoup
    soup = BeautifulSoup(html_text, 'html.parser')

    # Extract text content without HTML tags
    text = soup.get_text()

    # Remove special characters and extra whitespaces
    text = re.sub(r'\s+', ' ', text)  # Replace multiple whitespaces with a single space
    text = re.sub(r'[^\w\s]', '', text)  # Remove special characters

    # Normalize the text (convert to lowercase, for example)
    text = text.lower()

    return text

# %%
def text_summarise(content):
    url = "https://www.semrush.com/goodcontent/api/summary-generator/generate-summary/"
    payload = {
        "text": content,
        "format": "paragraph",
        "length_penalty": 0
    }
    
    response = requests.post(url, json=payload)

    if response.status_code == 200:
        response_data = response.json()
        return response_data["summary"]
    
    else:
        return 'None'

# %%
def serp(question):
    params = {
        "q": question,
        "hl": "en",
        "google_domain": "google.com",
        "api_key": "5188c793499d254054685e70d1ed8befe3386f3ac21e1a52af718c7ec80ccc89"
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    return results

# %%
directory_path = r"C:\Users\pkanv\OneDrive\Desktop\Acuration\probation task-2"
file_path = os.path.join(directory_path,'sunflare.txt')

# %%
questions = ['What is the official website of Sunflare solar company?'
'What is the bio of Sunflare solar company?',
'Where is the headquarters location of Sunflare solar company?',
'What are the products and services of Sunflare solar company?',
'What is the unique selling point (USP) of Sunflare solar company?',
'What is the value proposition of Sunflare solar company?',
'What is the target market of Sunflare solar company?',
'What is the market size of Sunflare solar company?',
'What is the competitive landscape of Sunflare solar company?',
'What are the business models of Sunflare solar company?',
'What are the revenue streams of Sunflare solar company?',
'What is the pricing model of Sunflare solar company?',
'What is the share price of Sunflare solar company?', 
'What is the profit margin of Sunflare solar company?',
'What is the total user base of Sunflare solar company?',
'How many paying customers do of Sunflare solar have?',
'What are the social media platforms of Sunflare solar company?',
'How many followers on social media platforms of Sunflare solar company',
'What is the funding info of Sunflare solar company?',
'What is the vision and mission of Sunflare solar company?',
'What are the key capabilities of Sunflare solar company?',
'What is the marketing strategy of Sunflare solar company?',
'What is the business strategy of Sunflare solar company?',
'Does Sunflare solar company have any collaborations or partnerships?',
'What is the cash flow of Sunflare solar company?']

# %%
for question in questions:
    results = serp(question)
    with open(file_path, 'a', encoding='utf-8') as file:
        file.write(f"\n\n\n")
        file.write(f"{question}\n")
        #results=serp(question)
        if "answer_box" in results:    
            answer=results["answer_box"].get('answer')
            file.write(f"\t{answer}\n")
            title=results["answer_box"].get('title')
            file.write(f"\t{title}\n")
            snippet=results["answer_box"].get('snippet')
            file.write(f"\t{snippet}\n")
            url=results["answer_box"].get('link')
            content,type = fetch_content(url)
            text = clean_html_and_extract_text(content)
            summarised_text = text_summarise(text)
            if summarised_text is not None:
                lines = summarised_text.split("\n")
                for line in lines:
                    file.write("\t" + line + "\n")
        if "organic_results" in results:
            for i in results["organic_results"]:
                title=i.get('title')
                file.write(f"\t{title}\n")
                snippet=i.get('snippet')
                file.write(f"\t{snippet}\n")                    
                url=i.get('link')
                content,type = fetch_content(url)
                text = clean_html_and_extract_text(content)
                summarised_text = text_summarise(text)
                if summarised_text is not None:
                    lines = summarised_text.split("\n")
                    for line in lines:
                        file.write("\t" + line + "\n")
        if "related_questions" in results:
            for i in results['related_questions']:
                question=i.get('question')
                file.write(f"\t{question}\n")
                title=i.get('title')
                file.write(f"\t\t{title}\n")
                snippet=i.get('snippet')
                file.write(f"\t\t{snippet}\n")
                url=i.get('link')
                content,type = fetch_content(url)
                text = clean_html_and_extract_text(content)
                summarised_text = text_summarise(text)
                if summarised_text is not None:
                    lines = summarised_text.split("\n")
                    for line in lines:
                        file.write("\t\t" + line + "\n")
# Out:
# Failed to fetch content from https://www.spaceweatherlive.com/en/solar-activity/solar-flares.html. Error: 403 Client Error: Forbidden for url: https://www.spaceweatherlive.com/en/solar-activity/solar-flares.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36464/3795320398.py in <module>
#      44                 url=i.get('link')
#      45                 content,type = fetch_content(url)
# ---> 46                 text = clean_html_and_extract_text(content)
#      47                 summarised_text = text_summarise(text)
#      48                 if summarised_text is not None:
#
# ~\AppData\Local\Temp/ipykernel_36464/313696466.py in clean_html_and_extract_text(html_text)
#       1 def clean_html_and_extract_text(html_text):
#       2     # Parse the HTML document using BeautifulSoup
# ----> 3     soup = BeautifulSoup(html_text, 'html.parser')
#       4
#       5     # Extract text content without HTML tags
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     310         if hasattr(markup, 'read'):        # It's a file-type object.
#     311             markup = markup.read()
# --> 312         elif len(markup) <= 256 and (
#     313                 (isinstance(markup, bytes) and not b'<' in markup)
#     314                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'NoneType' has no len()

# %%
results
# Out:
# {'search_metadata': {'id': '6592a8b90b5062fcbc863a76',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/7255da26a47fe65d/6592a8b90b5062fcbc863a76.json',
#   'created_at': '2024-01-01 11:57:45 UTC',
#   'processed_at': '2024-01-01 11:57:45 UTC',
#   'google_url': 'https://www.google.com/search?q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&oq=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&hl=en&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/7255da26a47fe65d/6592a8b90b5062fcbc863a76.html',
#   'total_time_taken': 0.83},
#  'search_parameters': {'engine': 'google',
#   'q': 'What is the official website of Sunflare solar company?What is the bio of Sunflare solar company?',
#   'google_domain': 'google.com',
#   'hl': 'en',
#   'device': 'desktop'},
#  'search_information': {'query_displayed': 'What is the official website of Sunflare solar company?What is the bio of Sunflare solar company?',
#   'total_results': 1640000,
#   'time_taken_displayed': 0.6,
#   'menu_items': [{'position': 1,
#     'title': 'Perspectives',
#     'link': 'https://www.google.com/search?sca_esv=594893628&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&uds=AMIYvT8nd3sDA7rE_xK4xkYVWsp6ViFeT78EStmw_Yt0zxptlH0jH_RdZk2W1ywRLqxBKoBgWuEJNKuaxc-lmkQWJrtwix0g9AAM--tKX_CV2rD-R1mT_bt3Z7eF_jjVGVHHFNTOYL5boaNF-Jv5XunLkjclUA3emmeOzhTrXcwNDDK0x0EvqUjuXcXHlkQhsT3VnRCPCO5d&udm=4&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQs6gLegQIChAB',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F'},
#    {'position': 2,
#     'title': 'Images',
#     'link': 'https://www.google.com/search?sca_esv=594893628&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&tbm=isch&source=lnms&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ0pQJegQIDBAB',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_images&gl=us&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F'},
#    {'position': 3,
#     'title': 'News',
#     'link': 'https://www.google.com/search?sca_esv=594893628&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&tbm=nws&source=lnms&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ0pQJegQIDhAB',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&tbm=nws'},
#    {'position': 4,
#     'title': 'Videos',
#     'link': 'https://www.google.com/search?sca_esv=594893628&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&tbm=vid&source=lnms&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ0pQJegQIDRAB',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_videos&gl=us&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F'},
#    {'position': 5,
#     'title': 'Shopping',
#     'link': 'https://www.google.com/search?sca_esv=594893628&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&tbm=shop&source=lnms',
#     'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_shopping&gl=us&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F'},
#    {'position': 6,
#     'title': 'Books',
#     'link': 'https://www.google.com/search?sca_esv=594893628&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&tbm=bks&source=lnms&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ0pQJegQIVBAB'},
#    {'position': 7,
#     'title': 'Maps',
#     'link': 'https://maps.google.com/maps?sca_esv=594893628&output=search&q=What+is+the+official+website+of+Sunflare+solar+company?What+is+the+bio+of+Sunflare+solar+company?&source=lnms&entry=mc'},
#    {'position': 8,
#     'title': 'Flights',
#     'link': 'https://www.google.com/travel/flights?sca_esv=594893628&output=search&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&source=lnms'},
#    {'position': 9,
#     'title': 'Finance',
#     'link': 'https://www.google.com/finance?sca_esv=594893628&output=search&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&source=lnms&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ0pQJegQIWBAB'}],
#   'organic_results_state': 'Results for exact spelling'},
#  'related_questions': [{'question': 'Who owns Sun Solar?',
#    'snippet': 'EXECUTIVE CHANGE: At right, Marc Lee is the new CEO of Sun Solar, succeeding Caleb Arthur, who remains owner and chair of the internal three-person board of directors.',
#    'title': 'Sun Solar hires new CEO | Springfield Business Journal',
#    'date': 'Sep 29, 2023',
#    'link': 'https://sbj.net/stories/sun-solar-hires-new-ceo,86474#:~:text=EXECUTIVE%20CHANGE%3A%20At%20right%2C%20Marc,three%2Dperson%20board%20of%20directors.',
#    'displayed_link': 'https://sbj.net › stories › sun-solar-hires-new-ceo,86474',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTMUN3Tvl7GlkhNzqL0TB3MDXfMTmtSVrg_JsLftVXk_Q&s',
#    'source_logo': None,
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...'},
#   {'question': 'When was the last sunflare?',
#    'title': 'Space weather facts',
#    'link': 'https://www.spaceweatherlive.com/en/solar-activity/solar-flares.html',
#    'displayed_link': 'https://www.spaceweatherlive.com › solar-activity › solar...',
#    'source_logo': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/5e72b274c776edbd2789b91632897d57a680cb5e68d2c17924a0d855d5bffa2d.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%%3D%3D'},
#   {'question': 'What is the meaning of Sunflare?',
#    'snippet': "A solar flare is an intense burst of radiation coming from the release of magnetic energy associated with sunspots. Flares are our solar system's largest explosive events. They are seen as bright areas on the sun and they can last from minutes to hours.",
#    'title': 'What is a solar flare? - NASA',
#    'link': 'https://www.nasa.gov/image-article/what-solar-flare/#:~:text=A%20solar%20flare%20is%20an,last%20from%20minutes%20to%20hours.',
#    'displayed_link': 'https://www.nasa.gov › image-article › what-solar-flare',
#    'source_logo': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/5e72b274c776edbd2789b91632897d572fe3745f1abd9c77419e48a45c7db964.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D%3D'},
#   {'question': 'Who is the CEO of Sunflare?',
#    'snippet': "HERE COMES THE SUN. Philip Gao, Sunflare's founder and CEO, had been following Graham's work.",
#    'title': 'Philip Gao',
#    'link': "https://www.sunflaresolar.com/transform/maui-house#:~:text=HERE%20COMES%20THE%20SUN.&text=Philip%20Gao%2C%20Sunflare's%20founder%20and,had%20been%20following%20Graham's%20work.",
#    'displayed_link': 'https://www.sunflaresolar.com › transform › maui-house',
#    'source_logo': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/5e72b274c776edbd2789b91632897d57e6e37fd460ba2ad1184f975fb4337e9d.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%2FIiwibGsiOiJHZ3h6ZFc1bWJHRnlaU0JqWlc4IiwiYnMiOiJjLU9TNEJJT3o4aFh5Q19QSzFZSUxzMVRDTTdQU1N5eWwxaGd6YVhBSlIyZWtacW5VSjVZckZDU2thcVFrMWhjb2xCY21wY0dWSkJxTF9IZGhVdVZTeUU4STdGRUlST2lJRGMxTVM4ekwxMGhQdzFrRWxUWkgxR0lRZmt3VmM2dV9xZ3EzbVlKTUFJQSIsImlkIjoiZmNfMSJ9'}],
#  'organic_results': [{'position': 1,
#    'title': 'Sunflare | Lightweight, Thin, Flexible Solar. Energy where you ...',
#    'link': 'https://www.sunflaresolar.com/',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.sunflaresolar.com/&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECBcQAQ',
#    'displayed_link': 'https://www.sunflaresolar.com',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b462b7b4495ed51afb99d3eec9300d71188.png',
#    'snippet': "Sunflare solar goes where traditional solar can't go. It's the only lightweight, thin, flexible and durable solar panel.",
#    'snippet_highlighted_words': ['Sunflare solar'],
#    'missing': ['bio'],
#    'must_include': {'word': 'bio',
#     'link': 'https://www.google.com/search?sca_esv=594893628&q=What+is+the+official+website+of+Sunflare+solar+company?What+is+the+%22bio%22+of+Sunflare+solar+company?&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ5t4CegQIGBAB'},
#    'source': 'Sunflare Solar'},
#   {'position': 2,
#    'title': 'What can thin, lightweight, flexible solar do for the world?',
#    'link': 'https://www.sunflaresolar.com/about',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.sunflaresolar.com/about&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECBAQAQ',
#    'displayed_link': 'https://www.sunflaresolar.com › about',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b46054e37e8098707547cfce5bb33dae87e.png',
#    'snippet': 'We are the first company to successfully mass-produce light, thin, flexible, and durable CIGS solar panels. These revolutionary panels can seamlessly and easily ...',
#    'snippet_highlighted_words': ['company', 'solar panels', 'panels'],
#    'missing': ['website', 'bio'],
#    'source': 'Sunflare Solar'},
#   {'position': 3,
#    'title': 'Sunflare Company and Product Overview',
#    'link': 'https://www.sunflaresolar.com/news/sunflare-company-and-product-overview',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.sunflaresolar.com/news/sunflare-company-and-product-overview&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECBIQAQ',
#    'displayed_link': 'https://www.sunflaresolar.com › news › sunflare-comp...',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b461a42ecb8df1ed8072bbdb5ebf8604243.png',
#    'snippet': 'Sunflare has been in the business of photovoltaic (PV) design and manufacturing since 2009. The company is headquartered in the U.S., but also has offices in ...',
#    'snippet_highlighted_words': ['Sunflare', 'business', 'company'],
#    'missing': ['website', 'bio'],
#    'source': 'Sunflare Solar'},
#   {'position': 4,
#    'title': 'Our Technology | Sunflare',
#    'link': 'https://www.sunflaresolar.com/our-technology',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.sunflaresolar.com/our-technology&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECBMQAQ',
#    'displayed_link': 'https://www.sunflaresolar.com › our-technology',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b46ce48ee440956609126ee104fcac82de6.png',
#    'snippet': "The game-changing solution we have all been looking for. It's light, flexible, thin, durable, and created to exacting specifications. Sunflare Flexible Solar ...",
#    'snippet_highlighted_words': ['Sunflare', 'Solar'],
#    'missing': ['website', 'bio'],
#    'source': 'Sunflare Solar'},
#   {'position': 5,
#    'title': 'Corporate Data - About SunFlare - SunFlare Co., Ltd.',
#    'link': 'https://www.sunflare.com/en/company/aboutus/',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.sunflare.com/en/company/aboutus/&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECA8QAQ',
#    'displayed_link': 'https://www.sunflare.com › company › aboutus',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b46887007dc97e1e87a756c733c0b1dbbf2.png',
#    'snippet': 'A corporate overview of SunFlare. Information on our Head Office, Representative Director and President, businesses and affiliated corporations can be found ...',
#    'snippet_highlighted_words': ['SunFlare'],
#    'source': 'SunFlare'},
#   {'position': 6,
#    'title': 'Contact Sunflare Solar',
#    'link': 'https://www.sunflaresolar.com/contact',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.sunflaresolar.com/contact&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECEYQAQ',
#    'displayed_link': 'https://www.sunflaresolar.com › contact',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b46d14931cb50505193fa52f75d06dd460f.png',
#    'snippet': 'For more information about Sunflare and our products, please fill out the contact form below. We are experiencing high call volume and customer support during ...',
#    'snippet_highlighted_words': ['Sunflare'],
#    'missing': ['website', 'bio'],
#    'source': 'Sunflare Solar'},
#   {'position': 7,
#    'title': 'Sunflare',
#    'link': 'https://www.linkedin.com/company/sunflare',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.linkedin.com/company/sunflare&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECEgQAQ',
#    'displayed_link': '890+ followers',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b46e24af89d154384a7d906dcefcf6978ac.png',
#    'snippet': 'Sunflare has perfected a new, proprietary technology revolutionizing CIGS solar. It produces light, thin, flexible and rugged modules that can go places never ...',
#    'snippet_highlighted_words': ['Sunflare', 'solar'],
#    'missing': ['bio'],
#    'must_include': {'word': 'bio',
#     'link': 'https://www.google.com/search?sca_esv=594893628&q=What+is+the+official+website+of+Sunflare+solar+company?What+is+the+%22bio%22+of+Sunflare+solar+company?&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ5t4CegQISRAB'},
#    'source': 'LinkedIn · Sunflare'},
#   {'position': 8,
#    'title': 'Sunflare Solar Private Limited, Ghaziabad - Manufacturer of ...',
#    'link': 'https://www.sunflareindia.net/',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.sunflareindia.net/&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECEIQAQ',
#    'displayed_link': 'https://www.sunflareindia.net',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b4616584d1a9d2bbadd3a3a1261807bf9b5.png',
#    'snippet': 'Sunflare Solar Pvt. Ltd. manufactures a wide range of solar LED lighting Products like LED Street light, LED home light, LED lantern, solar charge controller, ...',
#    'snippet_highlighted_words': ['Sunflare Solar'],
#    'missing': ['website', 'bio'],
#    'source': 'sunflareindia.net'},
#   {'position': 9,
#    'title': 'Flexible Solar Panel Market Size & Share 2023 to 2030',
#    'link': 'https://www.linkedin.com/pulse/flexible-solar-panel-market-size-share',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.linkedin.com/pulse/flexible-solar-panel-market-size-share&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECEsQAQ',
#    'displayed_link': '3 months ago',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b46288ba7545bb1effa10b3d0841e57cbb1.png',
#    'snippet': 'Flexible Solar Panel Market Size & Share 2023 to 2030 | Business Overview with SWOT Analysis | New Report of 115 Pages.',
#    'snippet_highlighted_words': ['Solar', 'Business'],
#    'source': 'LinkedIn · Research Industry Network'},
#   {'position': 10,
#    'title': "The Carrington Event: History's greatest solar storm",
#    'link': 'https://www.space.com/the-carrington-event',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.space.com/the-carrington-event&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQFnoECEUQAQ',
#    'displayed_link': 'https://www.space.com › ... › Solar System › The Sun',
#    'favicon': 'https://serpapi.com/searches/6592a8b90b5062fcbc863a76/images/30779a6eb120722653515ca029302b461ec433636a472940a8f91849eb89675f.png',
#    'date': 'Jun 24, 2022',
#    'snippet': "The Carrington Event took place in September 1859 and is one of history's largest solar storms. Events like this can wreak havoc on our ...",
#    'snippet_highlighted_words': ['solar'],
#    'source': 'Space.com'}],
#  'related_searches': [{'block_position': 1,
#    'query': 'sunflare solar panel review',
#    'link': 'https://www.google.com/search?sca_esv=594893628&q=Sunflare+solar+panel+Review&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ1QJ6BAhBEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=Sunflare+solar+panel+Review'},
#   {'block_position': 1,
#    'query': 'sunflare xplor',
#    'link': 'https://www.google.com/search?sca_esv=594893628&q=Sunflare+Xplor&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ1QJ6BAhAEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=Sunflare+Xplor'},
#   {'block_position': 1,
#    'query': 'sunflare today',
#    'link': 'https://www.google.com/search?sca_esv=594893628&q=Sunflare+today&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ1QJ6BAg_EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=Sunflare+today'},
#   {'block_position': 1,
#    'query': 'xplore solar reviews',
#    'link': 'https://www.google.com/search?sca_esv=594893628&q=Xplore+Solar+reviews&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ1QJ6BAg-EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=Xplore+Solar+reviews'},
#   {'block_position': 1,
#    'query': 'sunflare news',
#    'link': 'https://www.google.com/search?sca_esv=594893628&q=Sunflare+news&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ1QJ6BAg9EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=Sunflare+news'},
#   {'block_position': 1,
#    'query': 'sunflare png',
#    'link': 'https://www.google.com/search?sca_esv=594893628&q=Sunflare+png&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ1QJ6BAg8EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=Sunflare+png'},
#   {'block_position': 1,
#    'query': 'sunflare, flex 60',
#    'link': 'https://www.google.com/search?sca_esv=594893628&q=Sunflare+Flex+60&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ1QJ6BAg7EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=Sunflare+Flex+60'},
#   {'block_position': 1,
#    'query': 'sunflare powerfit 20 cost',
#    'link': 'https://www.google.com/search?sca_esv=594893628&q=Sunflare+PowerFit+20+cost&sa=X&ved=2ahUKEwjmjJG4kbyDAxUtpIkEHT5JAEcQ1QJ6BAg6EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=Sunflare+PowerFit+20+cost'}],
#  'pagination': {'current': 1,
#   'next': 'https://www.google.com/search?q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&oq=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&hl=en&start=10&sourceid=chrome&ie=UTF-8',
#   'other_pages': {'2': 'https://www.google.com/search?q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&oq=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&hl=en&start=10&sourceid=chrome&ie=UTF-8',
#    '3': 'https://www.google.com/search?q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&oq=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&hl=en&start=20&sourceid=chrome&ie=UTF-8',
#    '4': 'https://www.google.com/search?q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&oq=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&hl=en&start=30&sourceid=chrome&ie=UTF-8',
#    '5': 'https://www.google.com/search?q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&oq=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&hl=en&start=40&sourceid=chrome&ie=UTF-8'}},
#  'serpapi_pagination': {'current': 1,
#   'next_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&start=10',
#   'next': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&start=10',
#   'other_pages': {'2': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&start=10',
#    '3': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&start=20',
#    '4': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&start=30',
#    '5': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en&q=What+is+the+official+website+of+Sunflare+solar+company%3FWhat+is+the+bio+of+Sunflare+solar+company%3F&start=40'}}}
